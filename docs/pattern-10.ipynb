# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-10"

entrypoint = pattern
app_cwl_file = f"../cwl-workflow/{pattern}.cwl"

try:
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys

    module_path = os.path.abspath(os.path.join("."))  # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from pathlib import Path

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-09-05 11:58:44.104 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from ../cwl-workflow/pattern-10.cwl...
# 2025-09-05 11:58:44.105 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from ../cwl-workflow/pattern-10.cwl...
# 2025-09-05 11:58:44.152 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 11:58:44.153 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 11:58:44.161 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 11:58:44.181 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 11:58:44.182 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning Workflow pattern-10...
# 2025-09-05 11:58:44.183 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning Workflow vegetation_indexes...
# 2025-09-05 11:58:44.184 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool clt...
# 2025-09-05 11:58:44.185 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning ExpressionTool flatten_array...
# 2025-09-05 11:58:44.185 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 11:58:44.186 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from ../cwl-workflow/pattern-10.cwl successfully load!

# %% [markdown]
# ## Application Package Pattern 10
#
# This pattern shows how to flatten an array of array of `Directory`

# %%
wf.plot()

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `indexes` | `string[]` | indexes | indexes to compute |
# | `items` | `Directory[]` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `subworkflow` | `#vegetation_indexes` | None | None |
# | `flatten` | `#flatten_array` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `Directory[]` | Vegetation indexes | Vegetation indexes from Landsat-8/9 acquisitions |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f".{entrypoint}.cwl"

with open(app_cwl_file, "w") as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-09-05 11:58:45.565 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 11:58:45.619 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 11:58:45.629 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 11:58:45.630 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 11:58:45.631 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 11:58:46.501 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 11:58:46.502 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-directory...
# 2025-09-05 11:58:46.502 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 11:58:46.503 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl successfully load!
# 2025-09-05 11:58:46.504 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 11:58:46.551 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 11:58:46.560 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 11:58:46.561 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 11:58:46.562 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 11:58:47.370 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 11:58:47.370 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-file...
# 2025-09-05 11:58:47.371 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 11:58:47.371 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl successfully load!
# 2025-09-05 11:58:47.372 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 11:58:47.424 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 11:58:47.435 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 11:58:47.436 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 11:58:47.437 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 11:58:48.470 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 11:58:48.470 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-super-stage-out...
# 2025-09-05 11:58:48.471 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 11:58:48.471 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl successfully load!
# 2025-09-05 11:58:48.472 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-09-05 11:58:48.472 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-09-05 11:58:48.472 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-09-05 11:58:48.473 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-09-05 11:58:48.474 | INFO     | eoap_cwlwrap.types:validate_stage_out:331 - Validating stage-out 'my-super-stage-out'...
# 2025-09-05 11:58:48.475 | INFO     | eoap_cwlwrap.types:validate_stage_out:353 - stage-out 'my-super-stage-out' is valid
# 2025-09-05 11:58:48.476 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:90 - Building the CWL Orchestrator Workflow...
# 2025-09-05 11:58:48.476 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:119 - Analyzing pattern-10 inputs...
# 2025-09-05 11:58:48.478 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-10/aoi: string
# 2025-09-05 11:58:48.479 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-10/epsg: string
# 2025-09-05 11:58:48.479 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-10/indexes: string[]
# 2025-09-05 11:58:48.480 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-10/items: Directory[]
# 2025-09-05 11:58:48.480 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:148 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-09-05 11:58:48.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:150 -   Converting Directory[] to URL-compatible type...
# 2025-09-05 11:58:48.482 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:154 -   Directory[] converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[]
# 2025-09-05 11:58:48.483 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:175 -   Array detected, 'scatter' required for reference:items
# 2025-09-05 11:58:48.483 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:195 -   Connecting 'app/items' to 'directory_stage_in_0' output...
# 2025-09-05 11:58:48.484 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:246 - Analyzing pattern-10 outputs...
# 2025-09-05 11:58:48.484 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:252 - * pattern-10/vegetation_indexes: Directory[]
# 2025-09-05 11:58:48.485 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:257 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-09-05 11:58:48.485 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:259 -   Converting Directory[] to URL-compatible type...
# 2025-09-05 11:58:48.486 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:263 -   Directory[] converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[]
# 2025-09-05 11:58:48.487 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:284 -   Array detected, scatter required for stac_catalog:app/vegetation_indexes
# 2025-09-05 11:58:48.487 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:304 -   Connecting 'app/vegetation_indexes' to 'stage_out_0' output...
# 2025-09-05 11:58:48.488 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:379 - Orchestrator Workflow built in 0.0124 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()

# %% [markdown]
# ### Workflow components diagram

# %%
wf.display_components_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=3989x1213>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-10/aoi | area of interest as a bounding box - This parameter is derived from pattern-10/aoi |
# | `epsg` | `string` | EPSG code - pattern-10/epsg | EPSG code - This parameter is derived from pattern-10/epsg |
# | `indexes` | `string[]` | indexes - pattern-10/indexes | indexes to compute - This parameter is derived from pattern-10/indexes |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `items` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[]` | Landsat-8/9 acquisition reference - pattern-10/items | Landsat-8/9 acquisition reference - This parameter is derived from pattern-10/items |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `app` | `#pattern-10` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[]` | Vegetation indexes | Vegetation indexes from Landsat-8/9 acquisitions |

# %% [markdown]
# ## Execution

# %%
from cwltool.main import main
from io import StringIO
import argparse
import yaml

# %%
params = {
    "aoi": "-118.985,38.432,-118.183,38.938",
    "epsg": "EPSG:4326",
    "indexes": ["ndvi", "ndwi"],
    "items": [
        {
            "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
            "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1",
        },
        {
            "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
            "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC09_L2SP_042033_20231015_02_T1",
        },
    ],
}
additional_params = {
    "another_input": "some_value",
    "s3_bucket": "my-bucket",
    "sub_path": "my/sub/path",
    "aws_access_key_id": "test",
    "aws_secret_access_key": "test",
    "region_name": "us-west-1",
    "endpoint_url": "https://s3.us-west-1.amazonaws.com",
}

with open(".params.yaml", "w") as f:
    yaml.dump({**params, **additional_params}, f)

# %%
parsed_args = argparse.Namespace(
    podman=False,
    debug=False,
    validate=False,
    outdir="./runs",
    workflow=f"{app_cwl_file}#main",
    job_order=[".params.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
    stderr=stream_err,
)

assert res == 0

print(stream_out.getvalue())
# Out:
# {
#     "vegetation_indexes": [
#         {
#             "value": "s3://my-bucket/my/sub/path-j97jpz/catalog.json",
#             "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#         },
#         {
#             "value": "s3://my-bucket/my/sub/path-9s4afe/catalog.json",
#             "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#         },
#         {
#             "value": "s3://my-bucket/my/sub/path-filyh6/catalog.json",
#             "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#         },
#         {
#             "value": "s3://my-bucket/my/sub/path-fv07f6/catalog.json",
#             "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#         }
#     ]
# }
