# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-9"

entrypoint = pattern
app_cwl_file = f'../cwl-workflow/{pattern}.cwl'

try: 
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys
    module_path = os.path.abspath(os.path.join('.')) # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from pathlib import Path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-08-14 20:23:56.011 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from ../cwl-workflow/pattern-9.cwl...
# 2025-08-14 20:23:56.020 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:23:56.021 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:23:56.024 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:23:56.025 | INFO     | cwl_loader:_clean_process:62 -   Cleaning Workflow pattern-9...
# 2025-08-14 20:23:56.025 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool clt...
# 2025-08-14 20:23:56.026 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!

# %% [markdown]
# ## Application Package Pattern 9
#
# The CWL includes:
#
# - one input parameter of type `Directory`
# - output parameter of type `Directory[]?`
#
# This scenario takes as input an acquisition, applies an algorithm and may or may not generate outputs

# %%
wf.plot()

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `indexes` | `string[]` | indexes | indexes to compute |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `[ null, Directory[] ]` | Vegetation indexes | Vegetation indexes |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f'.{entrypoint}.cwl'

with open(app_cwl_file, 'w') as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-08-14 20:23:56.317 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-in.cwl...
# 2025-08-14 20:23:56.608 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:23:56.609 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:23:59.795 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:23:59.796 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-asthonishing-stage-in-directory...
# 2025-08-14 20:23:59.796 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:23:59.796 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-in-file.cwl...
# 2025-08-14 20:24:00.067 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:24:00.068 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:24:03.872 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:24:03.873 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-asthonishing-stage-in-file...
# 2025-08-14 20:24:03.873 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:24:03.873 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-out.cwl...
# 2025-08-14 20:24:04.236 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:24:04.237 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:24:07.982 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:24:07.982 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-super-stage-out...
# 2025-08-14 20:24:07.983 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:24:07.983 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-08-14 20:24:07.983 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-08-14 20:24:07.983 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-08-14 20:24:07.984 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-08-14 20:24:07.984 | INFO     | eoap_cwlwrap.types:validate_stage_out:331 - Validating stage-out 'my-super-stage-out'...
# 2025-08-14 20:24:07.984 | INFO     | eoap_cwlwrap.types:validate_stage_out:353 - stage-out 'my-super-stage-out' is valid
# 2025-08-14 20:24:07.984 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:89 - Building the CWL Orchestrator Workflow...
# 2025-08-14 20:24:07.985 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:118 - Analyzing pattern-9 inputs...
# 2025-08-14 20:24:07.985 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-9/aoi: string
# 2025-08-14 20:24:07.985 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-9/epsg: string
# 2025-08-14 20:24:07.985 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-9/indexes: string[]
# 2025-08-14 20:24:07.986 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-9/item: Directory
# 2025-08-14 20:24:07.986 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:147 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-08-14 20:24:07.986 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:149 -   Converting Directory to URL-compatible type...
# 2025-08-14 20:24:07.987 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:153 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-08-14 20:24:07.987 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:194 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-08-14 20:24:07.987 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:245 - Analyzing pattern-9 outputs...
# 2025-08-14 20:24:07.987 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:251 - * pattern-9/vegetation_indexes: [ null, Directory[] ]
# 2025-08-14 20:24:07.987 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:256 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-08-14 20:24:07.988 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:258 -   Converting [ null, Directory[] ] to URL-compatible type...
# 2025-08-14 20:24:07.988 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:262 -   [ null, Directory[] ] converted to [ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[] ]
# 2025-08-14 20:24:07.989 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:283 -   Array detected, scatter required for stac_catalog:app/vegetation_indexes
# 2025-08-14 20:24:07.989 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:294 -   Nullable detected, 'when' required for stac_catalog:app/vegetation_indexes
# 2025-08-14 20:24:07.989 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:303 -   Connecting 'app/vegetation_indexes' to 'stage_out_0' output...
# 2025-08-14 20:24:07.989 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:378 - Orchestrator Workflow built in 0.0051 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()

# %% [markdown]
# ### Workflow components diagram

# %%
wf.display_components_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3129x1072>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-9/aoi | area of interest as a bounding box - This parameter is derived from pattern-9/aoi |
# | `epsg` | `string` | EPSG code - pattern-9/epsg | EPSG code - This parameter is derived from pattern-9/epsg |
# | `indexes` | `string[]` | indexes - pattern-9/indexes | indexes to compute - This parameter is derived from pattern-9/indexes |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-9/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-9/item |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `app` | `#pattern-9` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `[ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[] ]` | Vegetation indexes | Vegetation indexes |
