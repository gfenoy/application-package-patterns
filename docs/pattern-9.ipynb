# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-9"

entrypoint = pattern
app_cwl_file = f"../cwl-workflow/{pattern}.cwl"

try:
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys

    module_path = os.path.abspath(os.path.join("."))  # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from IPython.display import Markdown, display
import json

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-09-05 14:52:33.852 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from ../cwl-workflow/pattern-9.cwl...
# 2025-09-05 14:52:33.853 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from ../cwl-workflow/pattern-9.cwl...
# 2025-09-05 14:52:33.877 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 14:52:33.878 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 14:52:33.885 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 14:52:33.899 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 14:52:33.900 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning Workflow pattern-9...
# 2025-09-05 14:52:33.901 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool clt...
# 2025-09-05 14:52:33.901 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 14:52:33.902 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from ../cwl-workflow/pattern-9.cwl successfully load!

# %% [markdown]
# ## Application Package Pattern 9
#
# The CWL includes:
#
# - one input parameter of type `Directory`
# - output parameter of type `Directory[]?`
#
# This scenario takes as input an acquisition, applies an algorithm and may or may not generate outputs

# %%
wf.plot()

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `indexes` | `string[]` | indexes | indexes to compute |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `[ null, Directory[] ]` | Vegetation indexes | Vegetation indexes |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f".{entrypoint}.cwl"

with open(app_cwl_file, "w") as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-09-05 14:52:34.868 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 14:52:34.925 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 14:52:34.936 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 14:52:34.937 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 14:52:34.938 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 14:52:35.876 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 14:52:35.877 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-directory...
# 2025-09-05 14:52:35.877 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 14:52:35.878 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl successfully load!
# 2025-09-05 14:52:35.879 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 14:52:35.931 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 14:52:35.938 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 14:52:35.938 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 14:52:35.939 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 14:52:36.739 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 14:52:36.740 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-file...
# 2025-09-05 14:52:36.741 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 14:52:36.741 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl successfully load!
# 2025-09-05 14:52:36.741 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 14:52:36.793 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 14:52:36.801 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 14:52:36.802 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 14:52:36.803 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 14:52:37.845 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 14:52:37.845 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-super-stage-out...
# 2025-09-05 14:52:37.846 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 14:52:37.846 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl successfully load!
# 2025-09-05 14:52:37.847 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-09-05 14:52:37.847 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-09-05 14:52:37.847 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-09-05 14:52:37.847 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-09-05 14:52:37.848 | INFO     | eoap_cwlwrap.types:validate_stage_out:331 - Validating stage-out 'my-super-stage-out'...
# 2025-09-05 14:52:37.848 | INFO     | eoap_cwlwrap.types:validate_stage_out:353 - stage-out 'my-super-stage-out' is valid
# 2025-09-05 14:52:37.848 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:90 - Building the CWL Orchestrator Workflow...
# 2025-09-05 14:52:37.849 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:119 - Analyzing pattern-9 inputs...
# 2025-09-05 14:52:37.849 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-9/aoi: string
# 2025-09-05 14:52:37.850 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-9/epsg: string
# 2025-09-05 14:52:37.850 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-9/indexes: string[]
# 2025-09-05 14:52:37.851 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-9/item: Directory
# 2025-09-05 14:52:37.851 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:148 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-09-05 14:52:37.852 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:150 -   Converting Directory to URL-compatible type...
# 2025-09-05 14:52:37.852 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:154 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-09-05 14:52:37.854 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:195 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-09-05 14:52:37.854 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:246 - Analyzing pattern-9 outputs...
# 2025-09-05 14:52:37.855 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:252 - * pattern-9/vegetation_indexes: [ null, Directory[] ]
# 2025-09-05 14:52:37.855 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:257 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-09-05 14:52:37.855 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:259 -   Converting [ null, Directory[] ] to URL-compatible type...
# 2025-09-05 14:52:37.856 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:263 -   [ null, Directory[] ] converted to [ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[] ]
# 2025-09-05 14:52:37.858 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:284 -   Array detected, scatter required for stac_catalog:app/vegetation_indexes
# 2025-09-05 14:52:37.859 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:295 -   Nullable detected, 'when' required for stac_catalog:app/vegetation_indexes
# 2025-09-05 14:52:37.859 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:304 -   Connecting 'app/vegetation_indexes' to 'stage_out_0' output...
# 2025-09-05 14:52:37.860 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:379 - Orchestrator Workflow built in 0.0112 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()

# %% [markdown]
# ### Workflow components diagram

# %%
wf.display_components_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=3129x1072>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-9/aoi | area of interest as a bounding box - This parameter is derived from pattern-9/aoi |
# | `epsg` | `string` | EPSG code - pattern-9/epsg | EPSG code - This parameter is derived from pattern-9/epsg |
# | `indexes` | `string[]` | indexes - pattern-9/indexes | indexes to compute - This parameter is derived from pattern-9/indexes |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-9/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-9/item |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `app` | `#pattern-9` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `vegetation_indexes` | `[ null, https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI[] ]` | Vegetation indexes | Vegetation indexes |

# %% [markdown]
# ## Execution

# %%
from cwltool.main import main
from io import StringIO
import argparse
import yaml

# %%
params = {
    "aoi": "-118.985,38.432,-118.183,38.938",
    "epsg": "EPSG:4326",
    "indexes": ["ndvi", "none"],
    "item": {
        "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
        "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1",
    },
}
additional_params = {
    "another_input": "some_value",
    "s3_bucket": "my-bucket",
    "sub_path": "my/sub/path",
    "aws_access_key_id": "test",
    "aws_secret_access_key": "test",
    "region_name": "us-west-1",
    "endpoint_url": "https://s3.us-west-1.amazonaws.com",
}

with open(".params.yaml", "w") as f:
    yaml.dump({**params, **additional_params}, f)

md = f"""

### Inputs

```json
{json.dumps(params, indent=2)}
```
"""

display(Markdown(md))
# Out:
# ### Inputs
#
# ```json
# {"aoi": "-118.985,38.432,-118.183,38.938", "epsg": "EPSG:4326", "indexes": ["ndvi", "none"], "item": {"class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL", "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1"}}
# ```

# %%
parsed_args = argparse.Namespace(
    podman=False,
    debug=False,
    validate=False,
    outdir="./runs",
    workflow=f"{app_cwl_file}#main",
    job_order=[".params.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
    stderr=stream_err,
)

assert res == 0

md = f"""

### Outputs

```json
{stream_out.getvalue()}
```
"""

display(Markdown(md))
# Out:
# ### Outputs
#
# ```json
# {
#     "vegetation_indexes": [
#         {
#             "value": "s3://my-bucket/my/sub/path-ubbsam/catalog.json",
#             "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#         },
#         null
#     ]
# }
# ```
