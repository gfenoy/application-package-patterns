# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-11"

entrypoint = pattern
app_cwl_file = f'../cwl-workflow/{pattern}.cwl'

try: 
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys
    module_path = os.path.abspath(os.path.join('.')) # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from pathlib import Path
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-08-14 20:28:35.915 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from ../cwl-workflow/pattern-11.cwl...
# 2025-08-14 20:28:35.924 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:28:35.925 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:28:35.929 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:28:35.929 | INFO     | cwl_loader:_clean_process:62 -   Cleaning Workflow pattern-11...
# 2025-08-14 20:28:35.930 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool clt...
# 2025-08-14 20:28:35.930 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!

# %% [markdown]
# ## Application Package Pattern-11
#
# This pattern uses as input a `File` and a `Directory`

# %%
wf.plot()

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `bands` | `string[]` | bands used for the NDWI | bands used for the NDWI |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |
# | `dem` | `File` | Digital Elevation Model (DEM) | Digital Elevation Model (DEM) geotiff |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `Directory` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f'.{entrypoint}.cwl'

with open(app_cwl_file, 'w') as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-08-14 20:28:36.202 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-in.cwl...
# 2025-08-14 20:28:36.365 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:28:36.366 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:28:39.001 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:28:39.001 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-asthonishing-stage-in-directory...
# 2025-08-14 20:28:39.002 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:28:39.002 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-in-file.cwl...
# 2025-08-14 20:28:40.203 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:28:40.204 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:28:43.027 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:28:43.028 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-asthonishing-stage-in-file...
# 2025-08-14 20:28:43.028 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:28:43.029 | INFO     | cwl_loader:load_cwl_from_location:186 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/main/templates/stage-out.cwl...
# 2025-08-14 20:28:43.236 | INFO     | cwl_loader:load_cwl_from_yaml:117 - Updating the model to v1.2...
# 2025-08-14 20:28:43.237 | INFO     | cwl_loader:load_cwl_from_yaml:128 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-08-14 20:28:46.477 | INFO     | cwl_loader:load_cwl_from_yaml:136 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-08-14 20:28:46.478 | INFO     | cwl_loader:_clean_process:62 -   Cleaning CommandLineTool my-super-stage-out...
# 2025-08-14 20:28:46.478 | INFO     | cwl_loader:load_cwl_from_yaml:144 - CWL document successfully dereferenced!
# 2025-08-14 20:28:46.478 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-08-14 20:28:46.478 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-08-14 20:28:46.478 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-08-14 20:28:46.479 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-08-14 20:28:46.479 | INFO     | eoap_cwlwrap.types:validate_stage_out:331 - Validating stage-out 'my-super-stage-out'...
# 2025-08-14 20:28:46.479 | INFO     | eoap_cwlwrap.types:validate_stage_out:353 - stage-out 'my-super-stage-out' is valid
# 2025-08-14 20:28:46.479 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:89 - Building the CWL Orchestrator Workflow...
# 2025-08-14 20:28:46.480 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:118 - Analyzing pattern-11 inputs...
# 2025-08-14 20:28:46.480 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-11/aoi: string
# 2025-08-14 20:28:46.480 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-11/epsg: string
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-11/bands: string[]
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-11/item: Directory
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:147 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:149 -   Converting Directory to URL-compatible type...
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:153 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-08-14 20:28:46.481 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:194 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-08-14 20:28:46.482 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:134 - * pattern-11/dem: File
# 2025-08-14 20:28:46.482 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:147 -   File type detected, creating a related 'file_stage_in_0'...
# 2025-08-14 20:28:46.482 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:149 -   Converting File to URL-compatible type...
# 2025-08-14 20:28:46.482 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:153 -   File converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-08-14 20:28:46.483 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:194 -   Connecting 'app/dem' to 'file_stage_in_0' output...
# 2025-08-14 20:28:46.483 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:245 - Analyzing pattern-11 outputs...
# 2025-08-14 20:28:46.483 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:251 - * pattern-11/water_bodies: Directory
# 2025-08-14 20:28:46.484 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:256 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-08-14 20:28:46.484 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:258 -   Converting Directory to URL-compatible type...
# 2025-08-14 20:28:46.484 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:262 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-08-14 20:28:46.485 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:303 -   Connecting 'app/water_bodies' to 'stage_out_0' output...
# 2025-08-14 20:28:46.485 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:378 - Orchestrator Workflow built in 0.0062 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()

# %% [markdown]
# ### Workflow components diagram

# %%
wf.display_components_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=3494x1072>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-11/aoi | area of interest as a bounding box - This parameter is derived from pattern-11/aoi |
# | `epsg` | `string` | EPSG code - pattern-11/epsg | EPSG code - This parameter is derived from pattern-11/epsg |
# | `bands` | `string[]` | bands used for the NDWI - pattern-11/bands | bands used for the NDWI - This parameter is derived from pattern-11/bands |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-11/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-11/item |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-file/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-file/another_input |
# | `dem` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Digital Elevation Model (DEM) - pattern-11/dem | Digital Elevation Model (DEM) geotiff - This parameter is derived from pattern-11/dem |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `file_stage_in_0` | `#my-asthonishing-stage-in-file` | None | None |
# | `app` | `#pattern-11` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |
