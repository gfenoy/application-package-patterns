# %%
# %load_ext autoreload
# %autoreload 2

pattern = "pattern-11"

entrypoint = pattern
app_cwl_file = f"../cwl-workflow/{pattern}.cwl"

try:
    from docs.helpers import plot_cwl, wrap_cwl
except (ImportError, ModuleNotFoundError) as e:

    import os
    import sys

    module_path = os.path.abspath(os.path.join("."))  # or the path to your source code
    sys.path.insert(0, module_path)

from helpers import WorkflowViewer, WorkflowWrapper
from cwl_loader import dump_cwl
from pathlib import Path

# %%
wf = WorkflowViewer.from_file(app_cwl_file, entrypoint)
# Out:
# 2025-09-05 12:03:41.792 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from ../cwl-workflow/pattern-11.cwl...
# 2025-09-05 12:03:41.793 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from ../cwl-workflow/pattern-11.cwl...
# 2025-09-05 12:03:41.816 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 12:03:41.817 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 12:03:41.822 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 12:03:41.833 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 12:03:41.834 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning Workflow pattern-11...
# 2025-09-05 12:03:41.835 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool clt...
# 2025-09-05 12:03:41.835 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 12:03:41.836 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from ../cwl-workflow/pattern-11.cwl successfully load!

# %% [markdown]
# ## Application Package Pattern-11
#
# This pattern uses as input a `File` and a `Directory`

# %%
wf.plot()

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest | area of interest as a bounding box |
# | `epsg` | `string` | EPSG code | EPSG code |
# | `bands` | `string[]` | bands used for the NDWI | bands used for the NDWI |
# | `item` | `Directory` | Landsat-8/9 acquisition reference | Landsat-8/9 acquisition reference |
# | `dem` | `File` | Digital Elevation Model (DEM) | Digital Elevation Model (DEM) geotiff |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `step` | `#clt` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `Directory` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Data flow management

# %%
w = WorkflowWrapper(workflow=wf.workflow, entrypoint=entrypoint)
wrapped = w.wrap()

app_cwl_file = f".{entrypoint}.cwl"

with open(app_cwl_file, "w") as f:
    dump_cwl(process=wrapped, stream=f)
# Out:
# 2025-09-05 12:03:42.770 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 12:03:42.823 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl...
# 2025-09-05 12:03:42.832 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 12:03:42.834 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 12:03:42.835 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 12:03:43.672 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 12:03:43.673 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-directory...
# 2025-09-05 12:03:43.674 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 12:03:43.675 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in.cwl successfully load!
# 2025-09-05 12:03:43.675 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 12:03:43.725 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl...
# 2025-09-05 12:03:43.731 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 12:03:43.732 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 12:03:43.733 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 12:03:44.672 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 12:03:44.673 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-asthonishing-stage-in-file...
# 2025-09-05 12:03:44.673 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 12:03:44.673 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-in-file.cwl successfully load!
# 2025-09-05 12:03:44.674 | DEBUG    | cwl_loader:load_cwl_from_location:196 - Loading CWL document from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 12:03:44.726 | DEBUG    | cwl_loader:_load_cwl_from_stream:199 - Reading stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl...
# 2025-09-05 12:03:44.739 | DEBUG    | cwl_loader:load_cwl_from_stream:173 - CWL data of type <class 'ruamel.yaml.comments.CommentedMap'> successfully loaded from stream
# 2025-09-05 12:03:44.739 | DEBUG    | cwl_loader:load_cwl_from_yaml:124 - Updating the model of type 'CommentedMap' to version 'v1.2'...
# 2025-09-05 12:03:44.740 | DEBUG    | cwl_loader:load_cwl_from_yaml:135 - Raw CWL document successfully updated to v1.2! Now converting to the CWL model...
# 2025-09-05 12:03:45.668 | DEBUG    | cwl_loader:load_cwl_from_yaml:143 - Raw CWL document successfully updated to v1.2! Now dereferencing the FQNs...
# 2025-09-05 12:03:45.669 | DEBUG    | cwl_loader:_clean_process:66 -   Cleaning CommandLineTool my-super-stage-out...
# 2025-09-05 12:03:45.669 | DEBUG    | cwl_loader:load_cwl_from_yaml:151 - CWL document successfully dereferenced!
# 2025-09-05 12:03:45.670 | DEBUG    | cwl_loader:_load_cwl_from_stream:207 - Stream from https://raw.githubusercontent.com/eoap/application-package-patterns/refs/heads/develop/templates/stage-out.cwl successfully load!
# 2025-09-05 12:03:45.670 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-directory'...
# 2025-09-05 12:03:45.671 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-directory' is valid
# 2025-09-05 12:03:45.671 | INFO     | eoap_cwlwrap.types:_validate_stage_in:273 - Validating stage-in 'my-asthonishing-stage-in-file'...
# 2025-09-05 12:03:45.672 | INFO     | eoap_cwlwrap.types:_validate_stage_in:295 - stage-in 'my-asthonishing-stage-in-file' is valid
# 2025-09-05 12:03:45.672 | INFO     | eoap_cwlwrap.types:validate_stage_out:331 - Validating stage-out 'my-super-stage-out'...
# 2025-09-05 12:03:45.672 | INFO     | eoap_cwlwrap.types:validate_stage_out:353 - stage-out 'my-super-stage-out' is valid
# 2025-09-05 12:03:45.673 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:90 - Building the CWL Orchestrator Workflow...
# 2025-09-05 12:03:45.673 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:119 - Analyzing pattern-11 inputs...
# 2025-09-05 12:03:45.674 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-11/aoi: string
# 2025-09-05 12:03:45.674 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-11/epsg: string
# 2025-09-05 12:03:45.674 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-11/bands: string[]
# 2025-09-05 12:03:45.676 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-11/item: Directory
# 2025-09-05 12:03:45.676 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:148 -   Directory type detected, creating a related 'directory_stage_in_0'...
# 2025-09-05 12:03:45.676 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:150 -   Converting Directory to URL-compatible type...
# 2025-09-05 12:03:45.677 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:154 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-09-05 12:03:45.677 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:195 -   Connecting 'app/item' to 'directory_stage_in_0' output...
# 2025-09-05 12:03:45.678 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:135 - * pattern-11/dem: File
# 2025-09-05 12:03:45.678 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:148 -   File type detected, creating a related 'file_stage_in_0'...
# 2025-09-05 12:03:45.679 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:150 -   Converting File to URL-compatible type...
# 2025-09-05 12:03:45.679 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:154 -   File converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-09-05 12:03:45.680 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:195 -   Connecting 'app/dem' to 'file_stage_in_0' output...
# 2025-09-05 12:03:45.680 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:246 - Analyzing pattern-11 outputs...
# 2025-09-05 12:03:45.680 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:252 - * pattern-11/water_bodies: Directory
# 2025-09-05 12:03:45.681 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:257 -   Directory type detected, creating a related 'stage_out_0'...
# 2025-09-05 12:03:45.681 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:259 -   Converting Directory to URL-compatible type...
# 2025-09-05 12:03:45.682 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:263 -   Directory converted to https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI
# 2025-09-05 12:03:45.683 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:304 -   Connecting 'app/water_bodies' to 'stage_out_0' output...
# 2025-09-05 12:03:45.684 | INFO     | eoap_cwlwrap:_build_orchestrator_workflow:379 - Orchestrator Workflow built in 0.0110 seconds

# %%
wf = WorkflowViewer(cwl_file=app_cwl_file, workflow=wrapped, entrypoint="main")

wf.plot()

# %% [markdown]
# ### Workflow components diagram

# %%
wf.display_components_diagram()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=3494x1072>

# %% [markdown]
# ### Inputs

# %%
wf.display_inputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `aoi` | `string` | area of interest - pattern-11/aoi | area of interest as a bounding box - This parameter is derived from pattern-11/aoi |
# | `epsg` | `string` | EPSG code - pattern-11/epsg | EPSG code - This parameter is derived from pattern-11/epsg |
# | `bands` | `string[]` | bands used for the NDWI - pattern-11/bands | bands used for the NDWI - This parameter is derived from pattern-11/bands |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-directory/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-directory/another_input |
# | `item` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Landsat-8/9 acquisition reference - pattern-11/item | Landsat-8/9 acquisition reference - This parameter is derived from pattern-11/item |
# | `another_input` | `string` | Another Input - my-asthonishing-stage-in-file/another_input | An additional input for demonstration purposes - This parameter is derived from my-asthonishing-stage-in-file/another_input |
# | `dem` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Digital Elevation Model (DEM) - pattern-11/dem | Digital Elevation Model (DEM) geotiff - This parameter is derived from pattern-11/dem |
# | `s3_bucket` | `string` | my-super-stage-out/s3_bucket | This parameter is derived from: my-super-stage-out/s3_bucket |
# | `sub_path` | `string` | my-super-stage-out/sub_path | This parameter is derived from: my-super-stage-out/sub_path |
# | `aws_access_key_id` | `string` | my-super-stage-out/aws_access_key_id | This parameter is derived from: my-super-stage-out/aws_access_key_id |
# | `aws_secret_access_key` | `string` | my-super-stage-out/aws_secret_access_key | This parameter is derived from: my-super-stage-out/aws_secret_access_key |
# | `region_name` | `string` | my-super-stage-out/region_name | This parameter is derived from: my-super-stage-out/region_name |
# | `endpoint_url` | `string` | my-super-stage-out/endpoint_url | This parameter is derived from: my-super-stage-out/endpoint_url |

# %% [markdown]
# ### Steps

# %%
wf.display_steps()
# Out:
# | Id | Runs | Label | Doc |
# | --- | --- | --- | --- |
# | `directory_stage_in_0` | `#my-asthonishing-stage-in-directory` | None | None |
# | `file_stage_in_0` | `#my-asthonishing-stage-in-file` | None | None |
# | `app` | `#pattern-11` | None | None |
# | `stage_out_0` | `#my-super-stage-out` | None | None |

# %% [markdown]
# ### Outputs

# %%
wf.display_outputs()
# Out:
# | Id | Type | Label | Doc |
# | --- | --- | --- | --- |
# | `water_bodies` | `https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI` | Water bodies detected | Water bodies detected based on the NDWI and otsu threshold |

# %% [markdown]
# ## Execution

# %%
from cwltool.main import main
from io import StringIO
import argparse
import yaml

# %%
params = {
    "aoi": "-118.985,38.432,-118.183,38.938",
    "epsg": "EPSG:4326",
    "bands": ["green", "nir08"],
    "item": {
        "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
        "value": "https://planetarycomputer.microsoft.com/api/stac/v1/collections/landsat-c2-l2/items/LC08_L2SP_042033_20231007_02_T1",
    },
    "dem": {
        "class": "https://raw.githubusercontent.com/eoap/schemas/main/url.yaml#URL",
        "value": "https://elevationeuwest.blob.core.windows.net/copernicus-dem/COP30_hh/Copernicus_DSM_COG_10_N38_00_W119_00_DEM.tif",
    },
}
additional_params = {
    "another_input": "some_value",
    "s3_bucket": "my-bucket",
    "sub_path": "my/sub/path",
    "aws_access_key_id": "test",
    "aws_secret_access_key": "test",
    "region_name": "us-west-1",
    "endpoint_url": "https://s3.us-west-1.amazonaws.com",
}

with open(".params.yaml", "w") as f:
    yaml.dump({**params, **additional_params}, f)

# %%
parsed_args = argparse.Namespace(
    podman=False,
    debug=False,
    validate=False,
    outdir="./runs",
    workflow=f"{app_cwl_file}#main",
    job_order=[".params.yaml"],
)

stream_out = StringIO()
stream_err = StringIO()

res = main(
    args=parsed_args,
    stdout=stream_out,
    stderr=stream_err,
)

assert res == 0

print(stream_out.getvalue())
# Out:
# {
#     "water_bodies": {
#         "value": "s3://my-bucket/my/sub/path-brgifr/catalog.json",
#         "type": "https://raw.githubusercontent.com/eoap/schemas/main/string_format.yaml#URI"
#     }
# }
